# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.0)
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84

# %%
## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import cv2
import tensorflow as tf
from tensorflow import keras
from keras import layers
from functools import partial

import warnings
warnings.filterwarnings('ignore')
AUTO = tf.data.experimental.AUTOTUNE

# %%
## Loading Dataset for Dog Breed Classification

# %%
from zipfile import ZipFile
data_path = 'dog-breed-identification.zip'

with ZipFile(data_path, 'r') as zip:
    zip.extractall()
    print('The data set has been extracted.')
# Out:
# The data set has been extracted.

# %%
## Exploratory Data Analysis

# %%
df = pd.read_csv('labels.csv')
df.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
df.shape
# Out:
# (10222, 2)

# %%
df['breed'].nunique()
# Out:
# 120

# %%
plt.figure(figsize=(10, 5))
df['breed'].value_counts().plot.bar()
plt.axis('off')
plt.show()

# %%
df['filepath'] = 'train/' + df['id'] + '.jpg'
df.head()
# Out:
#                                  id             breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever
#
#                                      filepath
# 0  train/000bec180eb18c7604dcecc8fe0dba07.jpg
# 1  train/001513dfcb2ffafc82cccf4d8bbaba97.jpg
# 2  train/001cdf01b096e06d78e9e5112d419397.jpg
# 3  train/00214f311d5d2247d5dfe4fe24b2303d.jpg
# 4  train/0021f9ceb3235effd7fcde7f7538ed62.jpg

# %%
plt.subplots(figsize=(10, 10))
for i in range(12):
    plt.subplot(4, 3, i+1)

    # Selecting a random image
    # index from the dataframe.
    k = np.random.randint(0, len(df))
    img = cv2.imread(df.loc[k, 'filepath'])
    plt.imshow(img)
    plt.title(df.loc[k, 'breed'])
    plt.axis('off')
plt.show()

# %%
le = LabelEncoder()
df['breed'] = le.fit_transform(df['breed'])
df.head()
# Out:
#                                  id  breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07     19
# 1  001513dfcb2ffafc82cccf4d8bbaba97     37
# 2  001cdf01b096e06d78e9e5112d419397     85
# 3  00214f311d5d2247d5dfe4fe24b2303d     15
# 4  0021f9ceb3235effd7fcde7f7538ed62     49
#
#                                      filepath
# 0  train/000bec180eb18c7604dcecc8fe0dba07.jpg
# 1  train/001513dfcb2ffafc82cccf4d8bbaba97.jpg
# 2  train/001cdf01b096e06d78e9e5112d419397.jpg
# 3  train/00214f311d5d2247d5dfe4fe24b2303d.jpg
# 4  train/0021f9ceb3235effd7fcde7f7538ed62.jpg

# %%
##  Data Preparation

# %%
features = df['filepath']
target = df['breed']

X_train, X_val, Y_train, Y_val = train_test_split(features, target,
                                      test_size=0.15,
                                      random_state=10)

X_train.shape, X_val.shape
# Out:
# ((8688,), (1534,))

# %%
##  Image Augmentation

# %%
# !pip install --user albumentations
# !pip install --user opencv-python
# Out:
# Collecting albumentations
#   Using cached albumentations-2.0.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from albumentations) (1.26.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from albumentations) (1.14.1)
# Requirement already satisfied: PyYAML in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from albumentations) (6.0.2)
# Collecting pydantic>=2.9.2 (from albumentations)
#   Using cached pydantic-2.10.5-py3-none-any.whl.metadata (30 kB)
# Collecting albucore==0.0.23 (from albumentations)
#   Using cached albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from albucore==0.0.23->albumentations) (3.11.3)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9.2->albumentations)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Using cached albumentations-2.0.0-py3-none-any.whl (273 kB)
# Using cached albucore-0.0.23-py3-none-any.whl (14 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached pydantic-2.10.5-py3-none-any.whl (431 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Installing collected packages: opencv-python-headless, annotated-types, pydantic, albucore, albumentations
# Successfully installed albucore-0.0.23 albumentations-2.0.0 annotated-types-0.7.0 opencv-python-headless-4.10.0.84 pydantic-2.10.5
# Requirement already satisfied: opencv-python in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\anany\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.0)

# %%
import albumentations as A

transforms_train = A.Compose([
    A.VerticalFlip(p=0.2),
    A.HorizontalFlip(p=0.7),
    A.CoarseDropout(p=0.5),
    A.RandomGamma(p=0.5),
    A.RandomBrightnessContrast(p=1)
])

# %%
img = cv2.imread('train/00792e341f3c6eb33663e415d0715370.jpg')
plt.imshow(img)
plt.show()

# %%
augments = [A.VerticalFlip(p=1), A.HorizontalFlip(p=1),
            A.CoarseDropout(p=1), A.CLAHE(p=1)]

plt.subplots(figsize=(10, 10))
for i, aug in enumerate(augments):
    plt.subplot(2, 2, i+1)
    aug_img = aug(image=img)['image']
    plt.imshow(aug_img)
plt.show()

# %%
## Building the Input Pipeline

# %%
def aug_fn(img):
    aug_data = transforms_train(image=img)
    aug_img = aug_data['image']

    return aug_img


@tf.function
def process_data(img, label):
    aug_img = tf.numpy_function(aug_fn,
                                [img],
                                Tout=tf.float32)

    return img, label


def decode_image(filepath, label=None):

    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img)
    img = tf.image.resize(img, [128, 128])
    img = tf.cast(img, tf.float32) / 255.0

    if label == None:
        return img

    return img, tf.one_hot(indices=label,
                           depth=120,
                           dtype=tf.float32)

# %%
train_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_train, Y_train))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(partial(process_data), num_parallel_calls=AUTO)
    .batch(32)
    .prefetch(AUTO)
)

val_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_val, Y_val))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(32)
    .prefetch(AUTO)
)

# %%
for img, label in train_ds.take(1):
  print(img.shape, label.shape)
# Out:
# (32, 128, 128, 3) (32, 120)

# %%
## Model Building Using Transfer Learning

# %%
### 1.Load Pre-trained InceptionV3 Model

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

pre_trained_model = InceptionV3(
    input_shape=(128, 128, 3),
    weights='imagenet',
    include_top=False
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 146s 2us/step

# %%
### 2.Inspect the Model’s Depth

# %%
len(pre_trained_model.layers)
# Out:
# 311

# %%
### 3.Freeze Pre-Trained Layers

# %%
for layer in pre_trained_model.layers: 
  layer.trainable = False

last_layer = pre_trained_model.get_layer('mixed7') 
# Access the output shape from the output tensor of the layer
print('last layer output shape: ', last_layer.output.shape) 
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 6, 6, 768)

# %%
### 4.Define the Custom Model Architecture

# %%
# Model Architecture
x = layers.Flatten()(last_output)
x = layers.Dense(256, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
x = layers.BatchNormalization()(x)
output = layers.Dense(120, activation='softmax')(x)

model = keras.Model(pre_trained_model.input, output)

# Model Compilation
model.compile(
    optimizer='adam',
    loss=keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.AUC()]
)

# %%
### 5.Implement Callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('val_auc') is not None and logs.get('val_auc') > 0.99:
            print('\n Validation accuracy has reached upto 90% so, stopping further training.')
            self.model.stop_training = True

es = EarlyStopping(patience=3,
                monitor='val_auc',
                restore_best_weights=True,
                mode='max')

lr = ReduceLROnPlateau(monitor='val_loss',
                    patience=2,
                    factor=0.5,
                    verbose=1)

# %%
## Train the Model

# %%
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=50,
                    verbose=1,
                    callbacks=[es, lr, myCallback()])
# Out:
# Epoch 1/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 161s 565ms/step - auc: 0.7111 - loss: 4.3700 - val_auc: 0.9361 - val_loss: 2.5878 - learning_rate: 0.0010
# Epoch 2/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 146s 536ms/step - auc: 0.9632 - loss: 2.2099 - val_auc: 0.9433 - val_loss: 2.3489 - learning_rate: 0.0010
# Epoch 3/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 148s 543ms/step - auc: 0.9917 - loss: 1.1884 - val_auc: 0.9268 - val_loss: 2.4497 - learning_rate: 0.0010
# Epoch 4/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - auc: 0.9994 - loss: 0.4814
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 162s 596ms/step - auc: 0.9994 - loss: 0.4811 - val_auc: 0.9145 - val_loss: 2.4898 - learning_rate: 0.0010
# Epoch 5/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 157s 575ms/step - auc: 0.9998 - loss: 0.1707 - val_auc: 0.9257 - val_loss: 2.3409 - learning_rate: 5.0000e-04

# %%
history_df = pd.DataFrame(history.history) 
history_df.loc[:, ['loss', 'val_loss']].plot() 
history_df.loc[:, ['auc', 'val_auc']].plot() 
plt.show()
